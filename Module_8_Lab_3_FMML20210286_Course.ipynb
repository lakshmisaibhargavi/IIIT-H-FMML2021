# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmisaibhargavi/IIIT-H-FMML2021/blob/main/Module_8_Lab_3_FMML20210286_Course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-07-28 09:35:48--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   268MB/s    in 0.3s
#
# 2022-07-28 09:35:49 (268 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 25956  1512.07928v1  We propose a novel weakly-supervised semantic ...    cs
# 15683  1601.05768v1  This paper discusses SYNTAGMA, a rule based NL...    cs
# 4456   1712.00996v1  Machine learning approaches hold great potenti...  stat
# 11007   1310.2931v2  A predictor that is deployed in a live product...  stat
# 11564  1606.02275v1  Markov chain Monte Carlo (MCMC) is one of the ...    cs
# ...             ...                                                ...   ...
# 25317  1507.06149v1  Deep Neural nets (NNs) with millions of parame...    cs
# 12267  1711.00629v1  This paper proposes a practical approach for a...  stat
# 7641   1802.06167v3  We present Generative Adversarial Capsule Netw...  stat
# 32373  1503.02946v2  The apsis toolkit presented in this paper prov...    cs
# 2030   1802.04443v1  The learnability of different neural architect...    cs
#
#                                                    title  year  \
# 25956  Learning Transferrable Knowledge for Semantic ...  2015
# 15683  Syntax-Semantics Interaction Parsing Strategie...  2016
# 4456   Learning to detect chest radiographs containin...  2017
# 11007             Feedback Detection for Live Predictors  2013
# 11564  Measuring the reliability of MCMC inference wi...  2016
# ...                                                  ...   ...
# 25317  Data-free parameter pruning for Deep Neural Ne...  2015
# 12267  Sleep Stage Classification Based on Multi-leve...  2017
# 7641   CapsuleGAN: Generative Adversarial Capsule Net...  2018
# 32373  apsis - Framework for Automated Optimization o...  2015
# 2030   On Characterizing the Capacity of Neural Netwo...  2018
#
#                                                 keywords
# 25956  [supervised, segmentation, algorithm, convolut...
# 15683  [discusses, addressing, syntactic, ambiguity, ...
# 4456   [approaches, potential, automated, detection, ...
# 11007  [predictor, production, predictions, fulfillin...
# 11564  [workhorses, probabilistic, inference, notorio...
# ...                                                  ...
# 25317  [parameters, performance, parameters, individu...
# 12267  [practical, automatic, classification, framewo...
# 7641   [generative, adversarial, framework, convoluti...
# 32373  [presented, framework, hyperparameter, optimiz...
# 2030   [learnability, different, architectures, chara...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 25956    [supervised, segmentation, algorithm, convolut...
# 15683    [discusses, addressing, syntactic, ambiguity, ...
# 4456     [approaches, potential, automated, detection, ...
# 11007    [predictor, production, predictions, fulfillin...
# 11564    [workhorses, probabilistic, inference, notorio...
#                                ...
# 22357    [maximizing, observations, optimization, essen...
# 3888     [convolutional, potentially, significant, comp...
# 1329     [convolutional, excellent, classification, exc...
# 11195    [answering, approximation, iteration, approxim...
# 22985    [selection, regression, construct, regression,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8839 words.
# Out of those 4522 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6662dcac-475c-4a48-bf0a-58e6896e7788" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6662dcac-475c-4a48-bf0a-58e6896e7788")) {                    Plotly.newPlot(                        "6662dcac-475c-4a48-bf0a-58e6896e7788",                        [{"x":["foreground","attention","generates","challenging","combining","segmentations","available","techniques","annotations","highlighted","knowledge","exclusive","substantially","microsoft","decoupled","algorithm","approaches","categories","performance","supervised","subsequently","different","architecture","convolutional","demonstrates","presented","highlights","segmentation","auxiliary","mechanism","strategies","disambiguation","addressing","generation","innovative","components","selective","management","ambiguity","interaction","information","addresses","described","semantics","interpretation","syntactic","resources","discusses","providing","solutions","constituent","constraints","reduction","containing","detection","annotated","architectures","difficult","potential","competing","historical","corresponding","informing","advantages","recurrent","localisation","exploring","typically","propagated","associated","automated","algorithms","delineated","demonstrate","estimated","comparison","accordingly","pulmonary","radiographs","annotation","methodologies","empirical","indicating","radiological","promising","classification","reinforcement","predictive","inference","predictions","predictor","methodology","predictors","introduce","production","fulfilling","currently","randomization","simulated","relevance","reliability","approximate","bidirectional","technique","languages","workhorses","posterior","importance","challenge","integrate","probabilistic","introduced","experiments","divergences","validating","representations","notoriously","symmetrized","effectiveness","particularly","expectation","divergence","distribution","programming","measuring","annealing","extractors","detectors","combination","processing","framework","databases","evaluated","competition","classifiers","preprocessing","retinopathy","candidate","considering","uncertainty","interested","minimization","minimizes","decomposable","baselines","especially","precision","maximizing","performing","functions","efficiently","optimization","minimizing","application","requiring","penalizing","specified","parameter","stochastic","depending","distributed","intercept","mapreduce","interesting","distinguishes","iterative","regression","coefficients","validation","penalized","improvement","derivatives","characterize","monotonic","generative","differential","flexibility","experimental","parameters","implementing","particular","competitive","expressiveness","methodological","quantification","applications","constraining","scalability","formulation","constraint","variational","inequality","extensively","including","convolution","discussed","resolution","computationally","intersection","efficient"],"y":[10,194,65,278,113,22,307,387,61,5,352,6,33,10,4,809,415,76,901,194,29,754,257,373,71,215,15,232,34,127,87,16,33,138,11,120,14,51,22,93,691,42,60,109,72,57,69,22,95,147,11,163,101,64,353,72,118,172,144,18,28,131,3,86,157,6,35,100,9,109,106,644,2,569,57,125,20,5,1,56,16,137,15,1,115,480,119,58,200,76,11,58,11,340,17,3,43,2,57,44,22,116,29,241,110,1,42,90,135,50,162,139,611,5,7,221,8,2,202,76,31,29,225,130,36,6,12,36,137,299,527,59,139,37,120,31,5,58,74,89,29,62,17,5,55,113,59,18,76,201,174,293,40,252,36,2,30,111,128,38,100,2,4,86,8,74,115,32,59,4,141,11,45,18,117,26,32,364,252,17,255,136,7,3,13,395,5,39,68,103,56,5,43,265,37,54,119,95,19,397],"type":"bar"},{"x":["foreground","attention","generates","challenging","combining","segmentations","available","t ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4522,), (4522, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Dualing</span> <span style=''>GANs</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Generative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style=''>nets</span> <span style=''>(GANs)</span> <span style=''>are</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3037974683544304);'>promising</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style=''>modeling</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>from</span> <span style=''>samples</span> <span style=''>It</span> <span style=''>is</span> <span style=''>however</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>GAN</span> <span style=''>training</span> <span style=''>suffers</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instability</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>its</span> <span style=''>maximin</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>explore</span> <span style=''>ways</span> <span style=''>to</span> <span style=''>tackle</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instability</span> <span style=''>problem</span> <span style=''>by</span> <span style=''>dualizing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminator</span> <span style=''>We</span> <span style=''>start</span> <span style=''>from</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminators</span> <span style=''>in</span> <span style=''>which</span> <span style=''>case</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conjugate</span> <span style=''>duality</span> <span style=''>provides</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.41666666666666663);'>mechanism</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reformulate</span> <span style=''>the</span> <span style=''>saddle</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>into</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximization</span> <span style=''>problem</span> <span style=''>such</span> <span style=''>that</span> <span style=''>both</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generator</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminator</span> <span style=''>of</span> <span style=''>this</span> <span style=''>dualing</span> <span style=''>GAN</span> <span style=''>act</span> <span style=''>in</span> <span style=''>concert</span> <span style=''>We</span> <span style=''>then</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>how</span> <span style=''>to</span> <span style=''>extend</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuition</span> <span style=''>to</span> <span style=''>non</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulations</span> <span style=''>For</span> <span style=''>GANs</span> <span style=''>with</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminators</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>remove</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Dealing</span> <span style=''>with</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>classes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Likelihood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discrimination</span> <span style=''>or</span> <span style=''>Ranking</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>in</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>classes</span> <span style=''>The</span> <span style=''>number</span> <span style=''>of</span> <span style=''>classes</span> <span style=''>is</span> <span style=''>assumed</span> <span style=''>too</span> <span style=''>large</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>exact</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>normalisation</span> <span style=''>over</span> <span style=''>all</span> <span style=''>classes</span> <span style=''>To</span> <span style=''>account</span> <span style=''>for</span> <span style=''>this</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>directly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximates</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style=''>simple</span> <span style=''>approach</span> <span style=''>works</span> <span style=''>well</span> <span style=''>on</span> <span style=''>toy</span> <span style=''>problems</span> <span style=''>and</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competitive</span> <span style=''>with</span> <span style=''>recently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>relate</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>ranking</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>This</span> <span style=''>leads</span> <span style=''>us</span> <span style=''>to</span> <span style=''>suggest</span> <span style=''>a</span> <span style=''>specific</span> <span style=''>setting</span> <span style=''>for</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>threshold</span> <span style=''>in</span> <span style=''>the</span> <span style=''>ranking</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Sum</span> <span style=''>Product</span> <span style=''>Networks</span> <span style=''>for</span> <span style=''>Hybrid</span> <span style=''>Domains</span> <br/><br/><span style=''>While</span> <span style=''>all</span> <span style=''>kinds</span> <span style=''>of</span> <span style=''>mixed</span> <span style=''>data</span> <span style=''>from</span> <span style=''>personal</span> <span style=''>data</span> <span style=''>over</span> <span style=''>panel</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scientific</span> <span style=''>data</span> <span style=''>to</span> <span style=''>public</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.44);'>commercial</span> <span style=''>data</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collected</span> <span style=''>and</span> <span style=''>stored</span> <span style=''>building</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.372093023255814);'>graphical</span> <span style=''>models</span> <span style=''>for</span> <span style=''>these</span> <span style=''>hybrid</span> <span style=''>domains</span> <span style=''>becomes</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>Users</span> <span style=''>spend</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significant</span> <span style=''>amounts</span> <span style=''>of</span> <span style=''>time</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4736842105263157);'>parametric</span> <span style=''>form</span> <span style=''>of</span> <span style=''>the</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.4114832535885167);'>variables</span> <span style=''>(Gaussian</span> <span style=''>Poisson</span> <span style=''>Logit</span> <span style=''>etc)</span> <span style=''>involved</span> <span style=''>and</span> <span style=''>learning</span> <span style=''>the</span> <span style=''>mixed</span> <span style=''>models</span> <span style=''>To</span> <span style=''>make</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>task</span> <span style=''>easier</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>trainable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.5481927710843374);'>architecture</span> <span style=''>for</span> <span style=''>hybrid</span> <span style=''>domains</span> <span style=''>that</span> <span style=''>features</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style=''>queries</span> <span style=''>It</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Sum</span> <span style=''>Product</span> <span style=''>Networks</span> <span style=''>(SPNs)</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>piecewise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>leave</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style=''>together</span> <span style=''>with</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.751824817518248);'>nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditioning</span> <span style=''>steps</span> <span style=''>using</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Better</span> <span style=''>safe</span> <span style=''>than</span> <span style=''>sorry</span> <span style=''>Risky</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploitation</span> <span style=''>through</span> <span style=''>safe</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Exploration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploitation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>that</span> <span style=''>is</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizing</span> <span style=''>a</span> <span style=''>mapping</span> <span style=''>between</span> <span style=''>inputs</span> <span style=''>and</span> <span style=''>expected</span> <span style=''>outputs</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ubiquitous</span> <span style=''>to</span> <span style=''>many</span> <span style=''>real</span> <span style=''>world</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>situations</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>situations</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sometimes</span> <span style=''>require</span> <span style=''>us</span> <span style=''>to</span> <span style=''>avoid</span> <span style=''>certain</span> <span style=''>outcomes</span> <span style=''>at</span> <span style=''>all</span> <span style=''>cost</span> <span style=''>for</span> <span style=''>example</span> <span style=''>because</span> <span style=''>they</span> <span style=''>are</span> <span style=''>poisonous</span> <span style=''>harmful</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>otherwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dangerous</span> <span style=''>We</span> <span style=''>test</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>participants</span> <span style=''>behavior</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scenarios</span> <span style=''>in</span> <span style=''>which</span> <span style=''>they</span> <span style=''>have</span> <span style=''>to</span> <span style=''>find</span> <span style=''>the</span> <span style=''>optimum</span> <span style=''>of</span> <span style=''>a</span> <span style=''>function</span> <span style=''>while</span> <span style=''>at</span> <span style=''>the</span> <span style=''>same</span> <span style=''>time</span> <span style=''>avoid</span> <span style=''>outputs</span> <span style=''>below</span> <span style=''>a</span> <span style=''>certain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>threshold</span> <span style=''>In</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>we</span> <span style=''>find</span> <span style=''>that</span> <span style=''>Safe</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploitation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>describes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>participants</span> <span style=''>behavior</span> <span style=''>well</span> <span style=''>and</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>participants</span> <span style=''>seem</span> <span style=''>to</span> <span style=''>care</span> <span style=''>f ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12661870503597122)
# 	representation (0.12949640287769784)
# 	architecture (0.09244604316546763)
# 	information (0.24856115107913668)
# 	processing (0.10755395683453238)
# 	segmentation (0.08345323741007195)
# 	detection (0.12697841726618705)
# 	recognition (0.12985611510791367)
# 	different (0.2712230215827338)
# 	convolutional (0.13417266187050358)
#
# Some Statistics words are:
# 	variational (0.10445544554455445)
# 	statistical (0.1495049504950495)
# 	algorithm (0.38514851485148516)
# 	theoretical (0.15346534653465346)
# 	variables (0.14603960396039603)
# 	estimation (0.16930693069306932)
# 	distribution (0.18811881188118812)
# 	dimensional (0.1896039603960396)
# 	inference (0.20445544554455444)
# 	regression (0.18465346534653465)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="06d8e7c7-9985-4068-8076-00c382b666d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06d8e7c7-9985-4068-8076-00c382b666d0")) {                    Plotly.newPlot(                        "06d8e7c7-9985-4068-8076-00c382b666d0",                        [{"x":["foreground","attention","generates","challenging","combining","segmentations","available","techniques","annotations","highlighted","knowledge","exclusive","substantially","microsoft","decoupled","algorithm","approaches","categories","performance","supervised","subsequently","different","architecture","convolutional","demonstrates","presented","highlights","segmentation","auxiliary","mechanism","strategies","disambiguation","addressing","generation","innovative","components","selective","management","ambiguity","interaction","information","addresses","described","semantics","interpretation","syntactic","resources","discusses","providing","solutions","constituent","constraints","reduction","containing","detection","annotated","architectures","difficult","potential","competing","historical","corresponding","informing","advantages","recurrent","localisation","exploring","typically","propagated","associated","automated","algorithms","delineated","demonstrate","estimated","comparison","accordingly","pulmonary","radiographs","annotation","methodologies","empirical","indicating","radiological","promising","classification","reinforcement","predictive","inference","predictions","predictor","methodology","predictors","introduce","production","fulfilling","currently","randomization","simulated","relevance","reliability","approximate","bidirectional","technique","languages","workhorses","posterior","importance","challenge","integrate","probabilistic","introduced","experiments","divergences","validating","representations","notoriously","symmetrized","effectiveness","particularly","expectation","divergence","distribution","programming","measuring","annealing","extractors","detectors","combination","processing","framework","databases","evaluated","competition","classifiers","preprocessing","retinopathy","candidate","considering","uncertainty","interested","minimization","minimizes","decomposable","baselines","especially","precision","maximizing","performing","functions","efficiently","optimization","minimizing","application","requiring","penalizing","specified","parameter","stochastic","depending","distributed","intercept","mapreduce","interesting","distinguishes","iterative","regression","coefficients","validation","penalized","improvement","derivatives","characterize","monotonic","generative","differential","flexibility","experimental","parameters","implementing","particular","competitive","expressiveness","methodological","quantification","applications","constraining","scalability","formulation","constraint","variational","inequality","extensively","including","convolution","discussed","resolution","computationally","intersection","efficient","improving","significant","shuffling","cityscapes","utilizing","compromise","unconditional","literature","achievable","partitioning","utilities","assumption","discussion","partitions","existence","mechanisms","additively","coalition","characterizes","assumptions","asymptotically","incentive","considerable","structure","complexity","separable","fractional","preferences","maximization","computational","polynomial","investigate","estimation","theoretical","inapplicable","established","leveraged","guarantee","asymptotic","conjugate","encompassing","statistical","probability","generalized","interestingly","communicate","synthetic","communication","ungrounded","cooperative","emergence","informative","supervision","answering","ultimately","questions","vocabulary"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	integrands
# 	quadrature
# 	integrand
# 	quadratures
# 	sociology
# 	statistician
# 	judiciously
# 	cytometry
# 	intracellular
# 	interventional
# 	beautiful
# 	marginalization
# 	minimised
# 	prescribe
# 	workflows
# 	cumulants
# 	bivariate
# 	nonlinearly
# 	elucidating
# 	recombines
# Some words which never appear in Statistics papers:
# 	disambiguation
# 	symmetrized
# 	retinopathy
# 	shuffling
# 	cityscapes
# 	coalition
# 	incentive
# 	ungrounded
# 	entertainment
# 	formalisation
# 	programmer
# 	instruction
# 	replicator
# 	demystifying
# 	termination
# 	decidable
# 	decidability
# 	photographs
# 	propositional
# 	revisions

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.093867953715736e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7691666666666667
